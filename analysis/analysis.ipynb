# %%
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
ds = pd.read_csv('../build/out.txt',sep=' ')
ds.columns = ['event','nHit','x','y','z','time','eln','eDep','TrackID','???','particle']
#ds1 = ds1[(np.abs(ds1.particle)==13) & (ds1.x > 150)]
#ds2 = ds2[np.abs(ds2.particle)==13 & (ds2.x > 150)]
ds.head()
# Out:
#    event  nHit           x          y         z  time         eln      eDep  \
# 0     12     9  224.758802  -5.946145  0.803966   0.0  194.036674  6.820476
# 1     12     9  239.836953  -7.500000 -1.173464   0.0    0.228782  0.000000
# 2     12     9  239.809081  -7.719211 -1.500000   0.0    0.228782  0.000000
# 3     12     9  239.553016  -9.733184 -4.500000   0.0    0.228782  0.000000
# 4     12     9  239.455520 -10.500000 -5.642245   0.0    0.228782  0.000000
#
#    TrackID  ???  particle
# 0        1  111        13
# 1       16  110        22
# 2       16  103        22
# 3       16  102        22
# 4       16  101        22

# %%
sns.histplot(ds.x)
plt.show()
sns.histplot(ds.y)
plt.show()
sns.histplot(ds.z)
plt.show()

# %%
sns.scatterplot(x=ds.y,y=ds.z)
plt.show()
